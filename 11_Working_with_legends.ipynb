# %%
import matplotlib.pyplot as plt

x  = [1,2,3,4,5]
y = [45,23,34,65,20]
y1 = [41,60,13,66,13]
y2 = [30,45,13,25,13]

plt.figure(figsize= [6,3])
plt.plot(x,y, label = "male" )
plt.plot(x,y1, label = "female")
plt.plot(x,y2, label = "kids")
# plt.legend(["a1","a2","a3"], ncols = 2, loc= 3)

# to add the legens outside the fig
plt.legend(bbox_to_anchor = (0.7, 1.3), ncols = 2)
plt.show()
