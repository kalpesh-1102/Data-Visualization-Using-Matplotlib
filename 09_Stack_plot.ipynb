# %%
import matplotlib.pyplot as plt

days = [1,2,3,4,5,6,7]

NOP1 = [10,20,32,40,55,45,80]
NOP2 = [20,34,45,40,50,55,90]
NOP3 = [10,25,30,40,45,35,70]

plt.stackplot(days,NOP1,NOP2,NOP3, colors= ["pink","hotpink","magenta"], labels = ["week1","week2","week3"])
plt.legend()
plt.show()
